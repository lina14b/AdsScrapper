# %%
from pymongo import MongoClient
MONGO_URI = 'mongodb+srv://lina:lina@cluster0.st42f.mongodb.net/?retryWrites=true&w=majority'
client = MongoClient(MONGO_URI)
db = client['AdsScrappers']
collection = db['Ads']
# distinct_values = list(collection.distinct("state", {"ville": {"$exists": True}}))
distinct_states = collection.distinct('state')

# %%
len(distinct_states)
# Out:
# 25

# %%
i=0
for state in distinct_states[:24]:
 print(i,state)
 i+=1
# Out:
# 0 None
# 1 Ariana
# 2 Beja
# 3 Ben Arous
# 4 Bizerte
# 5 Gabes
# 6 Gafsa
# 7 Jendouba
# 8 Kairouan
# 9 Kasserine
# 10 Kebili
# 11 Kef
# 12 Mahdia
# 13 Manouba
# 14 Medenine
# 15 Monastir
# 16 Nabeul
# 17 Sfax
# 18 Sidi Bouzid
# 19 Siliana
# 20 Sousse
# 21 Tataouine
# 22 Tozeur
# 23 Tunis

# %%
i=0
for state in distinct_states[24:]:
 print(i,state)
 i+=1
# Out:
# 0 Zaghouan

# %%
states_of_tunisia = ['Ariana','Beja','Ben Arous','Bizerte','Gabes','Gafsa',
    'Jendouba','Kairouan','Kasserine','Kebili','Kef', 'Mahdia',
    'Manouba','Medenine','Monastir',
    'Nabeul','Sfax','Sidi Bouzid','Siliana','Sousse','Tataouine','Tozeur','Tunis','Zaghouan'
]
states_mapping = {
   '':'Ariana','Béja':'Beja','Ben arous':'Ben Arous','Bin ‘Arūs':'Ben Arous','Banzart':'Bizerte','Gabès':'Gabes','Qābis':'Gabes','':'Gafsa',
    'Jundūbah':'Jendouba','':'Kairouan','Al Qaşrayn':'Kasserine','Kébili':'Kebili','Le Kef':'Kef','Al Mahdīyah': 'Mahdia',
    'La Manouba':'Manouba','Djerba':'Medenine','Madanīn':'Medenine','Médenine':'Medenine','':'Monastir',
    'Hammamet':'Nabeul','Nābul':'Nabeul','Şafāqis':'Sfax','':'Sidi Bouzid','':'Siliana','Sūsah':'Sousse','':'Tataouine',
    '':'Tozeur','Gammarth':'Tunis','':'Zaghouan'
}
# states_mapping = {
#    '':'Ariana','Béja':'Beja','Ben arous':'Ben Arous','Bin ‘Arūs':'Ben Arous','Banzart':'Bizerte','Gabès':'Gabes','Qābis':'Gabes','':'Gafsa',
#     'Jundūbah':'Jendouba','':'Kairouan','Al Qaşrayn':'Kasserine','Kébili':'Kebili','Le Kef':'Kef','Al Mahdīyah': 'Mahdia',
#     'La Manouba':'Manouba','Djerba':'Medenine','Madanīn':'Medenine','Médenine':'Medenine','':'Monastir',
#     'Hammamet':'Nabeul','Nābul':'Nabeul','Şafāqis':'Sfax','':'Sidi Bouzid','':'Siliana','Sūsah':'Sousse','':'Tataouine',
#     '':'Tozeur','Gammarth':'Tunis','':'Zaghouan'
# }

# %%
from bienImmobilier import BienImmobilier
import time
import re
b=BienImmobilier()
list=b.readAll()

# %%
backup=list

# %%
list3=[]
j=0
for item in list:
    if  item['state']=="" or not item['state']:
        j+=1
        if not item['ville'] or item['ville']!=item['zone']:
         print (j,item['url'],item["zone"],item['ville'],"  -  ",item['state'])
         
        list3.append(item)
        # print (item['state'])
         
        # if "Manouba" in item['state']:item['state']: print (item['state'],"Manouba") 
        # if "Kef" in item['state']:item['state']: print (item['state'],"Kef")
    #    if "Gabès" in self.state: self.state="Gabes"
    #    if "Béja" in self.state: self.state="Beja"
    #    if "Médenine" in self.state: self.state="Medenine"
# Out:
# 434 http://www.tunisie-vente.com/DetailsOffre.asp?cod_ann=3186253 Mohamadia Cite El Omri   -   None
# 897 http://www.tunisie-vente.com/DetailsOffre.asp?cod_ann=3191676 Mohamadia Cite Ennacim   -   None
# 903 http://www.tunisie-vente.com/DetailsOffre.asp?cod_ann=3196191 Mohamadia Cite Bourbai   -   None
# 908 https://www.tayara.tn/item/une_villa_trs_haut_standing_S4_Chatt_Mariem_630f93ad76e94d2001e07fe6/ None None   -   None
# 909 https://www.tayara.tn/item/Terrain_pour_les_investisseurs_634a931332140be961aee89a/ None None   -   None
# 910 https://www.tayara.tn/item/Villa_Bloom_A_vendre_A_Menzah_1_63ac14038904729b1d9df24f/ None None   -   None
# 911 https://www.tayara.tn/item/PI608vente_appartement_Ain_Zaghouan_Nord_S3158m2_63a567f94be56f32cb7dd8a8/ None None   -   None
# 912 https://www.tayara.tn/item/Un_appartement_s2_vendre_Chatt_Meriem_63ac08648904729b1d9dee06/ None None   -   None
# ...

# %%
len(list3)
# Out:
# 922

# %%
#i=2183
i=0
skipped=0
villseisstate=0
getstate=0
jardin=[]
nones=[]
# for item in list:
while i<len(list3):
     if getstate>990:
      time.sleep(4000)
      getstate=0
   #   print("____________________________________________")
     bi=BienImmobilier()
     item =list3[i]
     bi.url=item['url']
     bi.ville=item['ville']
     bi.state=item['state']
     bi.zone=item ['zone']
     x=bi.verifyLocation()
     getstate+=x
     if bi.ville and "Jardin" in bi.ville:
        jardin.append(bi)
     if not bi.state:
        nones.append(bi)
    
     
     
     
     print(i,bi.ville,"--",bi.state," |! ",getstate)
     result = collection.update_one({'url': item['url']},{'$set': {'ville':bi.ville,'state':bi.state}})
     time.sleep(0)
     i=i+1
# Out:
# 0 Cite Oplympique -- Tunis  |!  1
# 1 Hammam Sousse Gharbi -- Sousse  |!  2
# 2 Monfleury -- Tunis  |!  3
# 3 Cite Ennasr -- Ariana  |!  4
# 4 Zone Industrielle El Meghira -- Ben Arous  |!  5
# 5 Cite Touristique -- Nabeul  |!  6
# 6 Cite Ennasr -- Ariana  |!  7
# 7 Cite Ennasr -- Ariana  |!  8
# 8 Barraket Essahel -- None  |!  8
# 9 Cite El Moustakbel (La Marsa) -- Tunis  |!  9
# 10 Zone Sultan -- None  |!  9
# 11 Route de Bir Bouregba -- None  |!  9
# 12 Zone Craxi -- None  |!  9
# 13 Bni khiar -- None  |!  9
# 14 Cite Ennasr -- Ariana  |!  10
# 15 Sidi Mahrsi -- None  |!  10
# 16 Sidi Mahrsi -- None  |!  10
# 17 AFH Mrezka -- None  |!  10
# 18 Zone Craxi -- None  |!  10
# 19 Zone Craxi -- None  |!  10
# 20 Zone Craxi -- None  |!  10
# 21 Barraket Essahel -- None  |!  10
# 22 Cite Plein Air -- Ben Arous  |!  11
# 23 Wed Errih -- None  |!  11
# 24 Zone Craxi -- None  |!  11
# 25 Sidi Mahrsi -- None  |!  11
# 26 AFH Mrezka -- None  |!  11
# 27 Zone Chraf -- None  |!  11
# ...

# %%
len(nones)
# Out:
# 0

# %%
for item in jardin:
    print(item.ville,item.state)
# Out:
# Jardins de Carthage Tunis
# Cite Jardins Bizerte
# Jardins d'el Menzah Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Cite Du Jardin Kef
# Jardins d'el Menzah Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins d'el Menzah Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins de Carthage Tunis
# Jardins d'el Menzah Tunis
# Jardins d'el Menzah Tunis
# Jardins d'el Menzah Tunis
# Jardins d'el Menzah Tunis
# Cite Jardins Bizerte
# Jardins de Carthage Tunis
# ...

# %%
from geopy.geocoders import GeoNames
from geopy.exc import GeocoderUnavailable

def get_state(city, country):
    try:
        geolocator = GeoNames(username="linab14")
        location = geolocator.geocode(f"{city}, {country}", exactly_one=True)
        if location is not None:
            state = location.raw.get('adminName1')
            state = state.replace(" Governorate", "")
            state = state.replace("Governorate", "")
            return state
    except GeocoderUnavailable as e:
         print("GeocoderUnavailable error:", e)
 
    return None

# %%
states_mapping = {
    'Ariana': 'Ariana',
    'Aryana': 'Ariana',
    'Aryanna': 'Ariana',
    'Ben Arous': 'Ben Arous',
    'Bin Arous': 'Ben Arous',
    'Ben Arouus': 'Ben Arous'
}

# %%
state = 'Aryana'

if state in states_mapping:
    value = states_mapping.get(state)
    print(f"The state '{state}' is found. The corresponding value is '{value}'.")
else:
    print(f"The state '{state}' is not found in the dictionary.")
# Out:
# The state 'Aryana' is found. The corresponding value is 'Ariana'.
