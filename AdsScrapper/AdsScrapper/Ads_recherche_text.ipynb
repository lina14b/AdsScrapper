# %% [markdown]
# IMPORTS

# %%
from pymongo import MongoClient
from bienImmobilier import BienImmobilier
import pandas as pd
import numpy as np
from collections import Counter
import re
from spellchecker import SpellChecker
from num2words import num2words
import nltk
from nltk.corpus import wordnet as wn
import spacy
import nltk
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import unicodedata
from transformationText import TransformationTexte
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lina\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lina\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lina\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# Fill dataframe with text

# %%
b=BienImmobilier()
#list=b.readAllOneMonth()
t=TransformationTexte()

# %%
client = MongoClient("mongodb+srv://lina:lina@cluster0.st42f.mongodb.net/test")
db = client["AdsScrappers"]
collection = db["Ads"]

# %%
spell = SpellChecker(language='fr')
mots = "surface,chauffage,climatisation,ascenseur"
liste_mots = mots.split(", ")
nlp = spacy.load('fr_core_news_sm')

# %%
list=b.readAll()
df = pd.DataFrame(list)
#df
b.ReadbyUrl(list[0]['url'])
b.print_maison()
# Out:
# Website: tunisie-vente.com
# URL: http://www.tunisie-vente.com/DetailsOffre.asp?cod_ann=3202290
# Code: 3202290
# Description: l'agence immo contact met en vente a el manzah 9b pour 1180000 dt une villa sur 3 niveaux ( terrain 498m et bati 550m ) avec chauffage central , jardin , studio , garage , titre bleu (wb3157)  frais de visite 20dt , commission agence 2 pourcent
# Price: 1180000
# Total Surface: 498
# Living Area Surface: None
# Address: el manzah 9b
# Country: Tunisie
# State: None
# Zone: El Menzah
# City: El Menzah 9
# Floor: None
# Parking Space: None
# Characteristics: []
# Number of Bedrooms: None
# Number of Bedrooms: None
# Number of Rooms: None
# Number of Rooms: None
# Number of Bathrooms: None
# Date Scraped: 2023-04-29 11:43:12.954000
# Date Inserted: 2023-04-18 00:00:00
# Date Modified: 2023-04-29 00:00:00
# Image URLs: ['www.tunisie-vente.com/upload2/202304/annonces-tunisie.net/photos/91639_20230418_144021.jpg', 'www.tunisie-vente.com/upload2/202304/annonces-tunisie.net/photos/91639_20230418_144040.jpg', 'www.tunisie-vente.com/upload2/202304/annonces-tunisie.net/photos/91639_20230418_144056.jpg', 'www.tunisie-vente.com/upload2/202304/annonces-tunisie.net/photos/91639_20230418_144121.jpg', 'www.tunisie-vente.com/upload2/202304/annonces-tunisie.net/photos/91639_20230418_144215.jpg']
# Construction Year: None
# total:  _ l agence mme contact met en vente a el mandat  pour  de une villa sur trois niveaux   terrain  et bat    avec chauffage central , jardin , studio , garage , titre bleu     frais de visite  , commission agence deux pourcent mandat el menzah 9

# %%
list[0]
# Out:
# {'website': 'tunisie-vente.com',
#  'url': 'http://www.tunisie-vente.com/DetailsOffre.asp?cod_ann=3202290',
#  'code': 3202290,
#  'description': "l'agence immo contact met en vente a el manzah 9b pour 1180000 dt une villa sur 3 niveaux ( terrain 498m et bati 550m ) avec chauffage central , jardin , studio , garage , titre bleu (wb3157)  frais de visite 20dt , commission agence 2 pourcent",
#  'price': 1180000,
#  'surfaceTotale': 498,
#  'surface_habitable': None,
#  'adresse': 'el manzah 9b',
#  'country': 'Tunisie',
#  'state': None,
#  'zone': 'El Menzah',
#  'ville': 'El Menzah 9',
#  'etage': None,
#  'place_voiture': None,
#  'characteristicslist': [],
#  'nombre_de_chambre': None,
#  'nombre_de_piece': None,
#  'nombre_de_salle_de_bain': None,
#  'datescraped': datetime.datetime(2023, 4, 29, 11, 43, 12, 954000),
#  'dateinstered': datetime.datetime(2023, 4, 18, 0, 0),
#  'datemodified': datetime.datetime(2023, 4, 29, 0, 0),
#  'imagesurlslist': ['www.tunisie-vente.com/upload2/202304/annonces-tunisie.net/photos/91639_20230418_144021.jpg',
#   'www.tunisie-vente.com/upload2/202304/annonces-tunisie.net/photos/91639_20230418_144040.jpg',
#   'www.tunisie-vente.com/upload2/202304/annonces-tunisie.net/photos/91639_20230418_144056.jpg',
#   'www.tunisie-vente.com/upload2/202304/annonces-tunisie.net/photos/91639_20230418_144121.jpg',
#   'www.tunisie-vente.com/upload2/202304/annonces-tunisie.net/photos/91639_20230418_144215.jpg'],
#  'anneeconstruction': None,
#  'TotalDescp': ' _ l agence mme contact met en vente a el mandat  pour  de une villa sur trois niveaux   terrain  et bat    avec chauffage central , jardin , studio , garage , titre bleu     frais de visite  , commission agence deux pourcent mandat el menzah 9'}

# %%
################################################################to be deleted
item=list[0]
i=0
#for item in list:
print(i)
i=i+1
test=0
newdescription=" _ " 
if item['description']:
    newdescription=newdescription+item['description']
    test=1
if item['adresse']:
     newdescription=newdescription+item['adresse']######+df['ville']
     test=1
if item['nombre_de_chambre']:
     newdescription=newdescription+' s+ ' +str(item['nombre_de_chambre'])
     test=1

#text = newdescription
text=t.TransormRawText(newdescription)
#     ######################### deal with s+
#  def number_to_words(match):
#         number = int(match.group(1))
#         if number==0:
#          return ""
#         else: return "sallon et {} chambres".format(num2words(number, lang='fr'))

#     # Replace patterns of the form "s+number" with "sallon et the number in letters"
#  text = re.sub(r"\s*\+\s*", "+", text)
#  text = re.sub(r"s\+(\d+)", number_to_words, text)
#  text = text.replace('éme', 'ème').replace(' ème', 'ème').replace('1er', '1ère').replace(' eme', 'ème').replace(' eau',' bain')
#  pattern = re.compile(r'\b([1-2]?\d{1,2}|1[0-9])\s*(ème|éme|er?)\b|[^\w\s,]|[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F1E0-\U0001F1FF]', re.MULTILINE)
#  text = pattern.sub(lambda match: num2words(int(match.group(1)), lang='fr') + match.group(2) if match.group(1) else ' ', text)
#  text = re.sub(r'\b(3[1-9]|[4-9]\d|\d{3,})\b', '', text)
#  text = re.sub(r'\b([0-9])\b', lambda match: ["zéro", "un", "deux", "trois", "quatre", "cinq", "six", "sept", "huit", "neuf"][int(match.group(1))], text)

#  text = re.sub(r'\b\w*\d+\w*\b', '', text)
#  text = re.sub(r'\b(\d+)(ère|ème|er?)\b', lambda match: num2words(int(match.group(1)), lang='fr') + match.group(2), text)
#  text = re.sub(r'\d+', ' ', text)
#  text = text.replace('\n', ' ').replace('\r', ' ')
#  misspelled = spell.unknown(text.split())
#  for word in misspelled:
#     corrected_word = spell.correction(word)
#     if corrected_word:
#         text = text.replace(word, corrected_word)
#  for mot in liste_mots:
#     target_word =mot
#     doc = nlp(text)
#     lemmas = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
#     synsets = wn.synsets(target_word, lang='fra')
#     synonyms = set()
#     for synset in synsets:
#         for lemma in synset.lemmas(lang='fra'):
#             synonyms.add(lemma.name())

#         # Check if any of the lemmas match any of the synonyms
#     detected_synonyms = set()
#     for lemma in lemmas:
#         if lemma in synonyms:
#             detected_synonyms.add(lemma)

#         # Print the detected synonyms
#     if len(detected_synonyms) > 0:
#         for ds in detected_synonyms:
#             text=text.replace(ds,mot)

if item['ville']:
     newdescription=text+ item['ville'].lower()
result = collection.update_one({'url': item['url']},{'$set': {'total_description': newdescription}})
print(text)

#  if result.modified_count == 1:
#       i=i+1
#       print(i)
# Out:
# 0
#  _ l agence mme contact met en vente a el mandat  pour  de une villa sur trois niveaux   terrain  et bat    avec chauffage central , jardin , studio , garage , titre bleu     frais de visite  , commission agence deux pourcent mandat

# %%
###############################################################################################################################
dfcopy=df

# %%
df
# Out:
#                   website                                                url  \
# 0       tunisie-vente.com  http://www.tunisie-vente.com/DetailsOffre.asp?...
# 1       tunisie-vente.com  http://www.tunisie-vente.com/DetailsOffre.asp?...
# 2       tunisie-vente.com  http://www.tunisie-vente.com/DetailsOffre.asp?...
# 3       tunisie-vente.com  http://www.tunisie-vente.com/DetailsOffre.asp?...
# 4       tunisie-vente.com  http://www.tunisie-vente.com/DetailsOffre.asp?...
# ...                   ...                                                ...
# 1552  tunisie-annonce.com  http://www.tunisie-annonce.com/DetailsAnnonceI...
# 1553    tunisie-vente.com  http://www.tunisie-vente.com/DetailsOffre.asp?...
# 1554  tunisie-annonce.com  http://www.tunisie-annonce.com/DetailsAnnonceI...
# 1555  tunisie-annonce.com  http://www.tunisie-annonce.com/DetailsAnnonceI...
# 1556  tunisie-annonce.com  http://www.tunisie-annonce.com/DetailsAnnonceI...
#
#          code                                        description    price  \
# 0     3202290  l'agence immo contact met en vente a el manzah...  1180000
# 1     3204477  cet appartement se situe dans une résidence ga...   150000
# 2     3199113  a vendre, un appartement au 1er étage s+3 haut...   270000
# 3     3199130  a vendre, un appartement au 1er étage s+3 haut...   270000
# 4     3204259  notre agence sweet home vous propose à la vent...   200000
# ...       ...                                                ...      ...
# 1552  3205502  notre agence ranime immo vous propose pour la ...   150000
# 1553  3205510  a vendre\rs+1, dans une residence de la simpar...   195000
# 1554  3205528  ketata.immo met en vente à ennasr2 derrière cl...   500000
# 1555  3205524  a vendre \nduplex s+3 dans un bel emplacement ...   450000
# 1556  3205526  ketata.immo met en vente à ennasr2 derrière mo...   340000
#
#       surfaceTotale  surface_habitable                              adresse  \
# 0             498.0                NaN                         el manzah 9b
# 1              60.0                NaN                                 None
# 2             111.0                NaN  avenue de tunis erriadh borj cédria
# 3             111.0                NaN  avenue de tunis erriadh borj cédria
# 4             107.0                NaN                                 None
# ...             ...                ...                                  ...
# 1552          130.0                NaN       a la plage el haouaria cap bon
# 1553            NaN                NaN                            menzah 9c
# 1554          220.0                NaN                                 None
# 1555          119.0                NaN                                 None
# 1556          140.0                NaN                              ennasr2
#
#       country      state  ... characteristicslist nombre_de_chambre  \
# 0     Tunisie       None  ...                  []              None
# 1     Tunisie       None  ...                  []              None
# 2     Tunisie       None  ...                  []              None
# 3     Tunisie       None  ...                  []              None
# 4     Tunisie       None  ...                  []              None
# ...       ...        ...  ...                 ...               ...
# 1552  Tunisie     Nabeul  ...                  []              None
# 1553  Tunisie       None  ...                  []              None
# 1554  Tunisie     Ariana  ...                  []              None
# 1555  Tunisie  Ben arous  ...                  []              None
# 1556  Tunisie     Ariana  ...                  []              None
#
#       nombre_de_piece  nombre_de_salle_de_bain             datescraped  \
# 0                 NaN                      NaN 2023-04-29 11:43:12.954
# 1                 NaN                      NaN 2023-04-29 11:44:59.037
# 2                 NaN                      NaN 2023-04-29 11:47:49.586
# 3                 NaN                      NaN 2023-04-29 11:48:02.796
# 4                 NaN                      NaN 2023-04-29 11:48:43.592
# ...               ...                      ...                     ...
# 1552              NaN                      NaN 2023-04-30 18:51:12.913
# 1553              NaN                      NaN 2023-04-30 18:51:23.839
# 1554              NaN                      NaN 2023-04-30 21:00:16.643
# 1555              NaN                      NaN 2023-04-30 21:00:25.750
# 1556              NaN                      NaN 2023-04-30 21:00:27.854
#
#      dateinstered  datemodified  \
# 0      2023-04-18    2023-04-29
# 1      2023-04-27    2023-04-29
# 2      2023-04-07    2023-04-29
# 3      2023-04-07    2023-04-29
# 4      2023-04-26    2023-04-29
# ...           ...           ...
# 1552   2023-04-30    2023-04-30
# 1553   2023-04-30    2023-04-30
# 1554   2023-04-30    2023-04-30
# 1555   2023-04-30    2023-04-30
# 1556   2023-04-30    2023-04-30
#
#                                          imagesurlslist anneeconstruction  \
# 0     [www.tunisie-vente.com/upload2/202304/annonces...               NaN
# 1     [www.tunisie-vente.com/upload2/202304/tunisie-...               NaN
# 2     [www.tunisie-vente.com/upload2/202304/annonces...               NaN
# 3     [www.tunisie-vente.com/upload2/202304/annonces...               NaN
# 4     [www.tunisie-vente.com/upload2/202304/tunisie-...               NaN
# ...                                                 ...               ...
# 1552  [www.tunisie-annonce.com/upload2/202304/tunisi...               NaN
# 1553  [www.tunisie-vente.com/upload2/202304/tunisie-...               NaN
# 1554  [www.tunisie-annonce.com/upload2/202304/tunisi...               NaN
# 1555                                                 []               NaN
# 1556                                                 []               NaN
#
#                                              TotalDescp
# 0     l'agence immo contact met en vente a el manzah...
# 1     cet appartement se situe dans une résidence ga...
# 2     a vendre, un appartement au 1er étage s+3 haut...
# 3     a vendre, un appartement au 1er étage s+3 haut...
# 4     notre agence sweet home vous propose à la vent...
# ...                                                 ...
# 1552                                               None
# 1553                                               None
# 1554                                               None
# 1555                                               None
# 1556                                               None
#
# [1557 rows x 24 columns]

# %%
df=dfcopy

# %%
df = df[df['description'].notnull()]

# %%
# df['description'] = df['description'].fillna(' ')
df['ville'] = df['ville'].fillna(' ')
df['adresse'] = df['adresse'].fillna(' ')
df['TotalDescp'] = df['TotalDescp'].fillna(' ')
df['nombre_de_chambre'] = df['nombre_de_chambre'].fillna(0)
df['TotalDescp_']=df['TotalDescp']+df['description']+df['adresse']+df['ville']+ 's+ ' + df['nombre_de_chambre'].astype(str)

# %%
null_count = df['TotalDescp_'].isnull().sum()
null_count
# Out:
# 0

# %%
df['TotalDescp_']
# Out:
# 0       l'agence immo contact met en vente a el manzah...
# 1       cet appartement se situe dans une résidence ga...
# 2       a vendre, un appartement au 1er étage s+3 haut...
# 3       a vendre, un appartement au 1er étage s+3 haut...
# 4       notre agence sweet home vous propose à la vent...
#                               ...
# 1552     notre agence ranime immo vous propose pour la...
# 1553     a vendre\rs+1, dans une residence de la simpa...
# 1554     ketata.immo met en vente à ennasr2 derrière c...
# 1555     a vendre \nduplex s+3 dans un bel emplacement...
# 1556     ketata.immo met en vente à ennasr2 derrière m...
# Name: TotalDescp_, Length: 1557, dtype: object

# %%
desp=df['TotalDescp_'].tolist()

# %%
spell = SpellChecker(language='fr')
mots = "surface,chauffage,climatisation,ascenseur"
liste_mots = mots.split(", ")
nlp = spacy.load('fr_core_news_sm')

# %%
i=0
for item in desp:
    print(i)
    i=i+1


    # define a sample string
    text = item

    #########################To loweer
    text= text.lower()
    ######################### deal with s+
    def number_to_words(match):
        number = int(match.group(1))
        if number==0:
         return ""
        else: return "sallon et {} chambres".format(num2words(number, lang='fr'))

    # Replace patterns of the form "s+number" with "sallon et the number in letters"
    text = re.sub(r"\s*\+\s*", "+", text)
    text = re.sub(r"s\+(\d+)", number_to_words, text)


    pattern = re.compile(r'\b([1-2]?\d{1,2}|3[0-9])\s*(ème|éme|er?)\b|[^\w\s,]|[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F1E0-\U0001F1FF]', re.MULTILINE)
    text = pattern.sub(lambda match: num2words(int(match.group(1)), lang='fr') + match.group(2) if match.group(1) else ' ', text)

    text = re.sub(r'\b(3[1-9]|[4-9]\d|\d{3,})\b', '', text)
    text = text.replace(' éme', 'ème').replace(' ème', 'ème').replace('1er', '1ère').replace(' eme', 'ème').replace(' eau',' bain')

    text = re.sub(r'\b(\d+)(ère|ème|er?)\b', lambda match: num2words(int(match.group(1)), lang='fr') + match.group(2), text)

    text = re.sub(r'\d+', ' ', text)
    text = text.replace('\n', ' ').replace('\r', ' ')



    # misspelled = spell.unknown(text.split())
    # for word in misspelled:
    #     corrected_word = spell.correction(word)
    #     # print("***")
    #     # print(corrected_word)
    #     # print(word)
    #     if corrected_word:
    #      text = text.replace(word, corrected_word)



    for mot in liste_mots:
        target_word =mot
        doc = nlp(text)
        lemmas = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
        synsets = wn.synsets(target_word, lang='fra')

        # Get the synonyms from the synsets
        synonyms = set()
        for synset in synsets:
            for lemma in synset.lemmas(lang='fra'):
                synonyms.add(lemma.name())

        # Check if any of the lemmas match any of the synonyms
        detected_synonyms = set()
        for lemma in lemmas:
            if lemma in synonyms:
                detected_synonyms.add(lemma)
        # Print the detected synonyms
        if len(detected_synonyms) > 0:
            for ds in detected_synonyms:
                print(ds,mot) 
                text=text.replace(ds,mot)


    # Define stopwords and lemmatizer
    stop_words = set(stopwords.words('french'))
    lemmatizer = WordNetLemmatizer()


    # Normalize text by removing accents and lowercase
    text = unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore').decode('utf-8').lower()

    # Tokenize text
    tokens = word_tokenize(text)

    # Remove stop words
    tokens = [token for token in tokens if token not in stop_words]

    # Lemmatize tokens
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]

    print(lemmatized_tokens)
# Out:
# 0
# ['agence', 'immo', 'contact', 'met', 'vente', 'a', 'el', 'manzah', 'b', 'dt', 'villa', 'niveaux', 'terrain', 'bati', 'chauffage', 'central', ',', 'jardin', ',', 'studio', ',', 'garage', ',', 'titre', 'bleu', 'wb', 'frais', 'visite', 'dt', ',', 'commission', 'agence', 'pourcent', 'el', 'manzah', 'b', 'tunisie', 'el', 'menzah', 'el', 'menzah', 'agence', 'immo', 'contact', 'met', 'vente', 'a', 'el', 'manzah', 'b', 'dt', 'villa', 'niveaux', 'terrain', 'bati', 'chauffage', 'central', ',', 'jardin', ',', 'studio', ',', 'garage', ',', 'titre', 'bleu', 'wb', 'frais', 'visite', 'dt', ',', 'commission', 'agence', 'pourcentel', 'manzah', 'bel', 'menzah']
# 1
# ['cet', 'appartement', 'situe', 'residence', 'gardee', 'propre', 'a', 'nouvelle', 'medina', 'compose', 'salon', 'balcon', ',', 'chambre', 'a', 'coucher', 'quant', 'a', 'cuisine', 'ouverte', 'salon', 'equipee', 'amenagee', 'element', 'rangements', ',', 'plaque', ',', 'hotte', 'four', 'salle', 'bain', 'equipe', 'chauffage', 'central', ',', 'climatiseur', 'place', 'parking', 'sou', 'sol', 'tunisie', 'nouvelle', 'medina', 'nouvelle', 'medinacet', 'appartement', 'situe', 'residence', 'gardee', 'propre', 'a', 'nouvelle', 'medina', 'compose', 'salon', 'balcon', ',', 'chambre', 'a', 'coucher', 'quant', 'a', 'cuisine', 'ouverte', 'salon', 'equipee', 'amenagee', 'element', 'rangements', ',', 'plaque', ',', 'hotte', 'four', 'salle', 'bain', 'equipe', 'chauffage', 'central', ',', 'climatiseur', 'place', 'parking', 'sou', 'sol', 'nouvelle', 'medina']
# 2
# ['a', 'vendre', ',', 'appartement', 'uner', 'etage', 'sallon', 'trois', 'chambres', 'haut', 'standing', 'm2', ',', 'md', 'situe', 'a', 'erriadh', 'residence', 'ezzahr', 'tres', 'securisee', 'allees', 'bordees', 'lampadaires', ',', 'carreaux', 'jardin', 'arbores', ',', 'abris', 'parking', 'reserve', 'porte', 'entree', 'blindee', 'serrures', 'multipoints', 'clef', 'securite', 'salon', 'bien', 'eclaire', 'porte', 'fenetre', 'donnant', 'terrasse', 'grandes', 'chambres', 'a', 'coucher', 'dressing', 'suite', 'parentale', 'bien', 'soignee', 'cuisine', 'entierement', 'equipee', 'contenant', 'evier', ',', 'plaque', 'cuisson', 'surmontee', 'hotte', ',', 'four', 'encastre', ',', 'bloc', 'rangements', 'tiroirs', 'sde', 'sdb', 'design', 'modernes', 'touche', 'elegance', 'sanitaires', '
onne', 'mexicaine', 'belle', 'plage', 'mansoura', ',', 'toute', 'villa', 'climatise', 'suite', ',', 'trois', 'cuisine', 'hautes', 'gammes', 'entierement', 'equipees', ',', 'salles', 'bain', 'privatives', 'comportes', 'douche', 'baignoires', 'grand', 'terrasse', 'm2', 'dispose', 'vue', 'degage', 'plage', ',', 'chemine', 'exterieure', 'document', 'titre', 'bleu', 'mansoura', 'kelibia', 'blanchekelibia']
# 10
# ['a', 'vendre', 'terrain', 'habitation', 'a', 'tahert', 'kelibia', 'situe', 'a', 'minute', 'a', 'pieds', 'centre', 'ville', 'superficie', 'm2', 'facade', 'metre', 'rue', 'metre', 'terrain', 'a', 'minute', 'voiture', 'plage', 'el', 'mansourah', 'terrain', 'titre', 'foncier', 'prix', 'dt', 'reference', 'vt', 'tel', 'whatsapp', 'kelibia', 'tunisie', 'kelibia', 'kelibiaa', 'vendre', 'terrain', 'habitation', 'a', 'tahert', 'kelibia', 'situe', 'a', 'minute', 'a', 'pieds', 'centre', 'ville', 'superficie', 'm2', 'facade', 'metre', 'rue', 'metre', 'terrain', 'a', 'minute', 'voiture', 'plage', 'el', 'mansourah', 'terrain', 'titre', 'foncier', 'prix', 'dt', 'reference', 'vt', 'tel', 'whatsapp', 'kelibiakelibia']
# 11
# ['a', 'vendre', 'terrain', 'habitation', 'a', 'el', 'marsa', 'kelibia', 'situe', 'deuxeme', 'position', 'corniche', 'kelibia', 'superficie', 'm2', 'facade', 'metre', 'rue', 'metre', 'terrain', 'titre', 'foncier', 'individuel', 'prix', 'dt', 'reference', 'vt', 'tel', 'whatsapp', 'kelibia', 'tunisie', 'kelibia', 'kelibiaa', 'vendre', 'terrain', 'habitation', 'a', 'el', 'marsa', 'kelibia', 'situe', 'deuxeme', 'position', 'corniche', 'kelibia', 'superficie', 'm2', 'facade', 'metre', 'rue', 'metre', 'terrain', 'titre', 'foncier', 'individuel', 'prix', 'dt', 'reference', 'vt', 'tel', 'whatsapp', 'kelibiakelibia']
# 12
# ['a', 'vendre', 'appartements', 'a', 'ezzahra', 'hammam', 'ghzeez', 'situe', 'a', 'metre', 'plage', 'superficie', 'm2', 'compose', 'deux', 'chambres', 'a', 'coucher', ',', 'salon', ',', 'cuisine', 'salle', 'bain', 'appartement', 'balcon', 'vue', 'mer', 'appartement', 'titre', 'foncier', 'fin', 'travaux', 'mar', 'prix', 'dt', 'reference', 'vt', 'tel', 'kelibia', 'tunisie', 'kelibia', 'kelibiaa', 'vendre', 'appartements', 'a', 'ezzahra', 'hammam', 'ghzeez', 'situe', 'a', 'metre', 'plage', 'superficie', 'm2', 'compose', 'deux', 'chambres', 'a', 'coucher', ',', 'salon', ',', 'cuisine', 'salle', 'bain', 'appartement', 'balcon', 'vue', 'mer', 'appartement', 'titre', 'foncier', 'fin', 'travaux', 'mar', 'prix', 'dt', 'reference', 'vt', 'tel', 'kelibiakelibia']
# 13
# 16
# ['agence', 'immo', 'contact', 'met', 'vente', 'a', 'el', 'menzah', 'b', 'loin', 'clinique', 'espoir', 'dt', 'plus', 'renove', 'chauffage', 'central', ',', 'climatisation', ',', 'troiseme', 'etage', 'sans', 'ascenseur', 'wb', 'frais', 'visite', 'dt', ',', 'commission', 'agence', 'pourcent', 'el', 'menzah', 'b', 'tunisie', 'el', 'menzah', 'el', 'menzah', 'agence', 'immo', 'contact', 'met', 'vente', 'a', 'el', 'menzah', 'b', 'loin', 'clinique', 'espoir', 'dt', 'plus', 'renove', 'chauffage', 'central', ',', 'climatisation', ',', 'troiseme', 'etage', 'sans', 'ascenseur', 'wb', 'frais', 'visite', 'dt', ',', 'commission', 'agence', 'pourcentel', 'menzah', 'bel', 'menzah']
# 17
# ['a', 'vendre', 'terrain', 'habitation', 'a', 'kerkouene', 'situe', 'a', 'metre', 'plage', 'superficie', 'm2', 'deux', 'facade', 'metre', 'deux', 'rue', 'metre', 'terrain', 'titre', 'foncier', 'prix', 'dt', 'reference', 'vt', 'tel', 'kelibia', 'tunisie', 'kelibia', 'kelibiaa', 'vendre', 'terrain', 'habitation', 'a', 'kerkouene', 'situe', 'a', 'metre', 'plage', 'superficie', 'm2', 'deux', 'facade', 'metre', 'deux', 'rue', 'metre', 'terrain', 'titre', 'foncier', 'prix', 'dt', 'reference', 'vt', 'tel', 'kelibiakelibia']
# 18
# ['agence', 'immo', 'contact', 'met', 'vente', 'a', 'el', 'menzah', 'b', 'loin', 'clinique', 'espoir', 'dt', 'plus', 'troiseme', 'etage', 'sans', 'ascenseur', 'wb', 'frais', 'visite', 'dt', ',', 'commission', 'agence', 'pourcent', 'el', 'menzah', 'b', 'tunisie', 'el', 'menzah', 'el', 'menzah', 'agence', 'immo', 'contact', 'met', 'vente', 'a', 'el', 'menzah', 'b', 'loin', 'clinique', 'espoir', 'dt', 'plus', 'troiseme', 'etage', 'sans', 'ascenseur', 'wb', 'frais', 'visite', 'dt', ',', 'commission', 'agence', 'pourcentel', 'menzah', 'bel', 'menzah']
# 19
# ['a', 'vendre', 'appartements', 'cours', 'construction', 'a', 'sidi', 'mansour', 'kelibia', 'situe', 'a', 'metre', 'plage', 'superficie', 'm2', 'compose', 'deux', 'chambres', 'a', 'coucher', ',', 'salon', ',', 'cuisine', 'salle', 'bain', 'appartement', 'belle', 'vue', 'mer', 'appartement', 'titre', 'foncier', 'fin', 'travaux', 'mar', 'prix', 'dt', 'reference', 'vt', 'tel', 'kelibia', 'tunisie', 'kelibia', 'kelibiaa', 'vendre', 'appartements', 'cours', 'construction', 'a', 'sidi', 'mansour', 'kelibia', 'situe', 'a', 'metre', 'plage', 'superficie', 'm2', 'compose', 'deux', 'chambres', 'a', 'coucher', ',', 'salon', ',', 'cuisine', 'salle', 'bain', 'appartement', 'belle', 'vue', 'mer', 'appartement', 'titre', 'foncier', 'fin', 'travaux', 'mar', 'prix', 'dt', 'reference', 'vt', 'tel', 'kelibiakelibia']
# ['vvc', 'a', 'vendre', 'villa', 'tres', 'haut', 'standing', 'situee', 'a', 'choutrana', 'quartier', 'calme', ',', 'residentiel', 'securise', 'maison', 'construite', 'terrain', 'm2', 'dispose', 'jardin', 'piscine', 'maison', 'composee', 'comme', 'suit', 'rez', 'chaussee', 'grand', 'salon', 'ouvre', 'cuisine', 'americaine', 'suite', 'invite', 'chambre', 'debarras', 'salle', 'bain', 'invite', 'etage', 'comprend', 'grand', 'salon', 'suite', 'salle', 'bain', 'douche', 'chacune', 'dressing', 'quatrieme', 'grande', 'suite', 'parentale', 'salle', 'bain', 'dressing', 'climatisation', 'chauffage', 'central', 'toutes', 'piece', 'store', 'terrasse', 'jardin', 'prix', 'vente', 'million', 'mille', 'dinar', 'plus', 'information', 'contactez', 'f', 'immo', 'choutrana', 'tunisie', 'soukra', 'chotrana', 'vvc', 'a', 'vendre', 'villa', 'tres', 'haut', 'standing', 'situee', 'a', 'choutrana', 'quartier', 'calme', ',', 'residentiel', 'securise', 'maison', 'construite', 'terrain', 'm2', 'dispose', 'jardin', 'piscine', 'maison', 'composee', 'comme', 'suit', 'rez', 'chaussee', 'grand', 'salon', 'ouvre', 'cuisine', 'americaine', 'suite', 'invite', 'chambre', 'debarras', 'salle', 'bain', 'invite', 'etage', 'comprend', 'grand', 'salon', 'suite', 'salle', 'bain', 'douche', 'chacune', 'dressing', 'quatrieme', 'grande', 'suite', 'parentale', 'salle', 'bain', 'dressing', 'climatisation', 'chauffage', 'central', 'toutes', 'piece', 'store', 'terrasse', 'jardin', 'prix', 'vente', 'million', 'mille', 'dinar', 'plus', 'information', 'contactez', 'f', 'immo', 'choutrana', 'chotrana']
# 23
# ['a', 'vendre', 'terrain', 'habitation', 'a', 'cite', 'el', 'bostene', 'kelibia', 'situe', 'deuxeme', 'position', 'route', 'principale', 'superficie', 'm2', 'deux', 'facade', 'metre', 'rue', 'metre', 'facade', 'metre', 'rue', 'metre', 'terrain', 'titre', 'foncier', 'prix', 'dt', 'reference', 'vt', 'tel', 'kelibia', 'tunisie', 'kelibia', 'kelibiaa', 'vendre', 'terrain', 'habitation', 'a', 'cite', 'el', 'bostene', 'kelibia', 'situe', 'deuxeme', 'position', 'route', 'principale', 'superficie', 'm2', 'deux', 'facade', 'metre', 'rue', 'metre', 'facade', 'metre', 'rue', 'metre', 'terrain', 'titre', 'foncier', 'prix', 'dt', 'reference', 'vt', 'tel', 'kelibiakelibia']
# 24
# ['exceptionnel', 'ste', 'akariet', 'sarraj', 'propose', 'appartement', 'type', 'sallon', 'deux', 'chambres', 'm2', 'situe', 'deuxeme', 'etage', 'ascanceur', 'residance', 'securise', 'garde', 'face', 'hotel', 'tej', 'marhaba', ',', 'sousse', 'endroit', 'a', 'proximite', 'toute', 'commodites', 'appartement', 'comme', 'suit', 'spacieux', 'salon', 'deux', 'chambres', 'a', 'coucher', 'cuisine', 'sechoir', 'salle', 'bain', 'prestations', 'chauffage', 'central', 'climatiseurs', 'prix', 'md', 'negociable', 'vente', 'agenceimmobiliere', 'akarietsa', 'rraj', 'tunisie', 'sousse', 'ville', 'cite', 'jaouharaexceptionnel', 'ste', 'akariet', 'sarraj', 'propose', 'appartement', 'type', 'sallon', 'deux', 'chambres', 'm2', 'situe', 'deuxeme', 'etage', 'asc
# 30
# ['agence', 'immobiliere', 'gharbi', 'met', 'vente', 'local', 'a', 'usage', 'commercial', 'situe', 'a', 'avenue', 'carthage', 'tunis', 'a', 'proximite', 'bh', 'banque', 'local', 'rdc', 'complexe', 'commercial', 'm2', 'carre', 'emplacement', 'ideal', 'toutes', 'activites', 'plus', 'information', 'veuillez', 'contacter', 'rue', 'carthage', 'tunisie', 'bab', 'bhar', 'bab', 'bharl', 'agence', 'immobiliere', 'gharbi', 'met', 'vente', 'local', 'a', 'usage', 'commercial', 'situe', 'a', 'avenue', 'carthage', 'tunis', 'a', 'proximite', 'bh', 'banque', 'local', 'rdc', 'complexe', 'commercial', 'm2', 'carre', 'emplacement', 'ideal', 'toutes', 'activites', 'plus', 'information', 'veuillez', 'contacter', 'rue', 'carthagebab', 'bhar']
# 31
# ['av', 'charmante', 'villa', 'niveaux', 'piscine', ',', 'situe', 'a', 'sidi', 'jdidi', ',', 'loin', 'min', 'voiture', 'a', 'hammamet', 'yasmine', 'zone', 'calme', ',', 'securise', 'entoure', 'villa', 'composee', 'rdc', 'salon', ',', 'cuisine', 'equipee', ',', 'chambre', 'a', 'coucher', ',', 'salle', 'douche', 'a', 'etage', 'deux', 'chambres', 'a', 'coucher', ',', 'salle', 'douche', 'terrasses', 'jardin', 'gazonnee', ',', 'abri', 'voiture', 'superficie', 'totale', 'superficie', 'couvert', 'prix', 'md', 'a', 'debattre', 'plus', 'info', 'appelez', 'whatsapp', 'hammamet', 'sud', 'tunisie', 'hammamet', 'hammametav', 'charmante', 'villa', 'niveaux', 'piscine', ',', 'situe', 'a', 'sidi', 'jdidi', ',', 'loin', 'min', 'voiture', 'a', 'hammamet', 'yasmine', 'zone', 'calme', ',', 'securise', 'entoure', 'villa', 'composee', 'rdc', 'salon', ',', 'cuisine', 'equipee', ',', 'chambre', 'a', 'coucher', ',', 'salle', 'douche', 'a', 'etage', 'deux', 'chambres', 'a', 'coucher', ',', 'salle', 'douche', 'terrasses', 'jardin', 'gazonnee', ',', 'abri', 'voiture', 'superficie', 'totale', 'superficie', 'couvert', 'prix', 'md', 'a', 'debattre', 'plus', 'info', 'appelez', 'whatsapp', 'hammamet', 'sudhammamet']
# 32
# ['a', 'vendre', 'a', 'mghira', 'zone', 'industrielle', ',', 'depot', 'bati', 'terrain', ',', 'surface', 'couverte', 'administration', 'deux', 'niveaux', 'loge', 'gardien', 'disponibles', 'titre', 'foncier', 'regle', 'document', 'disponibles', 'a', 'agence', 'tunisie', 'fouchana', 'zone', 'industrielle', 'el', 'meghiraa', 'vendre', 'a', 'mghira', 'zone', 'industrielle', ',', 'depot', 'bati', 'terrain', ',', 'surface', 'couverte', 'administration', 'deux', 'niveaux', 'loge', 'gardien', 'disponibles', 'titre', 'foncier', 'regle', 'document', 'disponibles', 'a', 'agence', 'zone', 'industrielle', 'el', 'meghira']
ir', 'bouragba', 'bir', 'bouregba', 'hammamet', 'nabeul', 'tunisie', 'nabeul', 'bir', 'bouregba', 'villa', 'ghaya', 'ref', 'v', 'tps', 'immobiliere', 'propose', 'a', 'vente', ',', 'coquette', 'villa', 'moderne', 'plain', 'pied', ',', 'jumelee', 'seul', 'cote', ',', 'bien', 'situe', 'zone', 'residentielle', 'villa', 'luxe', ',', 'securisee', ',', 'proche', 'toutes', 'commodites', ',', 'bien', 'calme', 'a', 'minute', 'voiture', 'centre', 'ville', 'hammamet', 'mer', 'cette', 'villa', 'composee', 'deux', 'spacieux', 'salon', 'baignes', 'soleil', 'grace', 'a', 'leurs', 'grandes', 'fenetres', 'porte', 'fenetre', ',', 'suite', 'parentale', 'salle', 'douche', 'moderne', 'muni', 'cabine', 'douche', 'encastree', ',', 'deuxieme', 'chambre', 'a', 'coucher', ',', 'hall', 'grand', 'placard', 'belle', 'cuisine', 'americaine', 'moderne', ',', 'richement', 'amenagee', 'disposant', 'coin', 'debarrat', 'amenage', 'meubles', 'rangement', 'enfin', 'deuxieme', 'salle', 'douche', 'moderne', 'a', 'exterieure', ',', 'beneficiez', 'jardin', 'gazonne', 'entourant', 'villa', 'trois', 'cote', ',', 'belle', 'terrasse', ',', 'douche', 'exterieure', 'entree', 'voiture', 'porte', 'coulissante', 'electrique', 'cette', 'villa', 'aussi', 'munie', 'trois', 'climatiseurs', ',', 'pre', 'installation', 'chauffage', 'central', 'gaz', 'ville', 'cours', 'toute', 'villa', 'decoree', 'gout', 'raffine', 'finition', 'tres', 'haut', 'standing', 'cette', 'perle', 'peut', 'etre', 'vendue', 'meubles', 'prix', 'mdt', 'agent', 'a', 'disposition', 'toutes', 'information', 'conseils', 'necessaires', 'afin', 'disposer', 'bien', 'veuillez', 'svp', 'contacter', 'mme', 'islem', 'maison', 'bir', 'bouragba', 'bir', 'bouregba', 'hammamet', 'nabeulbir', 'bouregba']
# 38
# ['a', 'vendre', 'a', 'borj', 'cedria', ',', 'immeuble', 'appartement', 'situe', 'quartier', 'residentiel', ',', 'opportunite', 'investisseurs', 'surface', 'terrain', 'm2', 'surface', 'couverte', 'm2', 'md', 'tunisie', 'hammam', 'chatt', 'borj', 'cedriaa', 'vendre', 'a', 'borj', 'cedria', ',', 'immeuble', 'appartement', 'situe', 'quartier', 'residentiel', ',', 'opportunite', 'investisseurs', 'surface', 'terrain', 'm2', 'surface', 'couverte', 'm2', 'md', 'borj', 'cedria']
# 39
# ['sallon', 'deux', 'chambres', 'maison', 'sfax', 'ville', 'sfax', 'ville', 'sfax', 'tunisie', 'sfax', 'sfax', 'ville', 'sallon', 'deux', 'chambres', 'maison', 'sfax', 'ville', 'sfax', 'ville', 'sfaxsfax', 'ville']
# 40
# ['maison', 'bord', 'mer', 'ref', 'v', 'a', 'vendre', 'chez', 'agence', 'tps', 'immobiliere', 'hammamet', ',', 'belle', 'maison', 'pied', 'bain', 'situee', 'a', 'nabeul', 'maison', 'plain', 'pied', ',', 'comporte', 'petit', 'salon', 'cuisine', 'americaine', ',', 'deux', 'chambres', 'a', 'coucher', ',', 'salle', 'bain', 'salle', 'bain', 'a', 'exterieur', ',', 'joli', 'jardin', 'gazonnee', 'parking', 'voiture', 'equipee', 'chauffage', 'central', 'climatisation', 'agent', 'a', 'disposition', 'toutes', 'information', 'conseils', 'necessaires', 'afin', 'disposer', 'bien', 'veuillez', 'svp', 'contacter', 'mme', 'hela', 'mme', 'hela', 'whatsapp', 'maison', 'nabeul', 'nabeul', 'ville', 'nabeul', 'nabeul', 'tunisie', 'nabeul', 'nabeul', 'ville', 'maison', 'bord', 'mer', 'ref', 'v', 'a', 'vendre', 'chez', 'agence', 'tps', 'immobiliere', 'hammamet', ',', 'belle', 'maison', 'pied', 'bain', 'situee', 'a', 'nabeul', 'maison', 'plain', 'pied', ',', 'comporte', 'petit', 'salon', 'cuisine', 'americaine', ',', 'deux', 'chambres', 'a', 'coucher', ',', 'salle', 'bain', 'salle', 'bain', 'a', 'exterieur', ',', 'joli', 'jardin', 'gazonnee', 'parking', 'voiture', 'equipee', 'chauffage', 'central', 'climatisation', 'agent', 'a', 'disposition', 'toutes', 'information', 'conseils', 'necessaires', 'afin', 'disposer', 'bien', 'veuillez', 'svp', 'contacter', 'mme', 'hela', 'mme', 'hela', 'whatsapp', 'maison', 'nabeul', 'nabeul', 'ville', 'nabeul', 'nabeulnabeul', 'ville']
# 41
# ...
# 1524
# ['mystras', 'immo', 'propose', 'a', 'vente', 'villa', 'familiale', 'a', 'el', 'mourouj', 'magnifiques', 'prestations', 'surface', 'habitable', 'superficie', 'terrain', 'nombre', 'chambres', 'suite', 'parentale', 'douche', 'a', 'italienne', 'salle', 'bain', 'separee', 'wc', 'salles', 'bain', 'coin', 'amenages', ',', 'ete', 'couvert', 'hiver', 'place', 'parking', 'sou', 'sol', 'autre', 'abri', 'voiture', 'autres', 'avantages', 'chauffage', 'central', 'climatiseurs', 'toutes', 'piece', 'store', 'electrique', 'aluminium', 'orientation', 'optimale', 'quartier', 'residentiel', 'tres', 'calme', 'bon', 'voisinage', 'tous', 'article', 'sanitaires', 'neufs', 'prix', 'dnt', 'papier', 'titre', 'foncier', 'regle', 'nb', 'rdc', 'peuvent', 'etre', 'amenages', 'logement', 'utiliser', 'comme', 'depot', 'stockage', 'hesitez', 'a', 'contacter', 'plus', 'information', 'el', 'mourouj']
# 1525
# ['v', 'appartement', 'gold', 'a', 'vendre', 'chez', 'agence', 'chez', 'agence', 'smart', 'owner', 'immobiliere', 'hammamet', ',', 'charmant', 'appartement', 'pied', 'bain', 'type', 'sallon', 'deux', 'chambres', 'si', 'rez', 'chaussee', ',', 'situe', 'residence', 'gardee', 'bien', 'securisee', 'piscine', 'collectif', 'appartement', 'comporte', 'grand', 'salon', ',', 'deux', 'chambres', 'a', 'coucher', 'donnant', 'mer', 'piscine', ',', 'cuisine', 'moderne', 'bien', 'equipe', 'sechoir', 'salle', 'bain', 'invite', 'tout', 'equipe', 'chauffage', 'central', 'climatisation', 'eventuelle', 'visite', 'plus', 'information', 'veuillez', 'svp', 'contacter', 'mme', 'khouloud', 'hammamethammamet']
# 1531
# ['avendre', 'lot', 'terrain', 'situe', 'a', 'jardins', 'elmanzah', 'cote', 'nouvel', 'ecole', 'isc', 'lotissement', 'bouchamawi', 'titre', 'individuel', 'plus', 'information', 'meherjardins', 'elmanzah', 'jardins', 'el', 'menzah']
# 1532
# ['vente', 'appartement', 'a', 'hammamet', 'immobilier', 'extra', 'met', 'vente', 'appartement', 'deuxeme', 'etage', 'situe', 'a', 'hammamet', 'a', 'superficie', 'm2', 'loge', 'salon', 'deux', 'chambres', 'a', 'coucher', 'cuisine', 'bien', 'equipee', 'element', 'salle', 'bain', 'terrasse', 'garage', 'sou', 'sol', 'chauffage', 'central', 'climatisations', 'disponibles', 'situation', 'juridique', 'titre', 'foncier', 'prix', 'dt', 'gsm', 'hammamethammamet']
# 1533
# ['villa', 'dana', 'av', 'a', 'vendre', 'belle', 'demeure', 'haut', 'standing', 'situee', 'nouvelle', 'cite', 'trouvant', 'face', 'hotel', 'ribat', 'quartier', 'calme', 'bon', 'voisinage', 'repartie', 'deux', 'niveaux', 'offre', 'rez', 'chaussee', 'spacieux', 'salon', 'salle', 'a', 'manger', 'agreable', 'coin', 'chemine', 'ouvert', 'terrasse', 'piscine', ',', 'cuisine', 'moderne', 'installee', ',', 'chambre', 'a', 'couche', 'salle', 'bain', 'quant', 'a', 'etage', 'compte', 'salon', 'trois', 'suite', 'villa', 'equipee', 'climatisation', 'chauffage', 'central', 'dispose', 'a', 'exterieur', 'parking', 'agreable', 'jardin', 'gazonne', 'entourant', 'belle', 'piscine', 'prix', 'dt', 'toutes', 'information', 'necessaires', 'eventuelle', 'visite', ',', 'pouvez', 'contacter', 'agence', 'mouin', 'immobilier', 'internationalhammamet', 'zone', 'theatrehammamet']
# 1534
# ['maison', 'sallon', 'deux', 'chambres', 'a', 'dt', 'contacter', 'kelibiakelibia']
# 1535
# ['a', 'md', 'kelibia', 'assemerkelibia']
# 1536
# ['a', 'vendre', 'parfum', 'homme', 'marque', 'versace', 'blue', 'jean', 'ml', 'made', 'in', 'italy', 'prix', 'dinar', 'sfax']
# 1537
# ['agence', 'immo', 'contact', 'met', 'vente', 'dt', 'a', 'el', 'manzah', 'bi', 'spacieux', 'plus', 'haut', 'standing', 'chauffage', 'central', ',', 'climatisation', ',', 'place', 'parking', 'sou', 'sol', 'cellier', ',', 'balcon', ',', 'sechoir', 'wb', 'frais', 'visite', 'dt', ',', 'commission', 'agence', 'pourcentel', 'manzah', 'bisel', 'menzah']
# 1538
# ['a', 'vendre', 'appartement', 'm2', 'huiteme', 'etage', 'jardins', 'carthage', 'cet', 'appartement', 'compose', 'comme', 'suit', 'cuisine', 'amenagee', 'equipee', 'salon', 'balcon', 'chambre', 'a', 'coucher', 'dressing', 'salle', 'bain', 'appartement', 'equipee', 'chauffage', 'centrale', 'deux', 'climatiseurs', 'hesitez', 'a', 'contacter', 'tous', 'renseignements', 'visites', 'jardins', 'carthagejardins', 'carthage']
# 1539
# ['a', 'vendre', 'appartement', 'sallon', 'chambres', 'a', 'aouina', ',', 'cite', 'al', 'wahat', 'place', 'parking', ',', 'sixeme', 'etage', 'double', 'ascenseurs', 'residence', 'gardee', 'bien', 'securisee', 'pres', 'toutes', 'commodites', 'compose', 'salon', ',', 'chambre', 'a', 'coucher', ',', 'cuisine', 'independante', 'element', 'rangement', ',', 'salle', 'bain', 'sechoir', 'appartement', 'equipe', 'chauffage', 'central', 'climatiseurs', 'visite', 'information', 'contacter', 'el', 'aouina']
# 1540
# ['a', 'vendre', ',', 'terrain', 'cloture', 'contenant', 'residence', 'nouvellement', 'construite', 'quartier', 'al', 'naseem', 'ariana', 'titre', 'bleu', 'certificat', 'entreprise', 'individuelle', 'superficie', 'totale', 'metre', 'carres', 'residence', 'nouvellement', 'construite', 'metre', 'carres', 'chambres', 'contient', 'tous', 'service', 'public', 'bain', ',', 'gaz', ',', 'electricite', ',', 'desinfection', 'emplacement', 'distinctif', ',', 'approche', 'commerciale', 'principale', 'million', 'appelez', 'cite', 'ennacim']
# 1541
# ['a', 'vendre', 'rez', 'chaussee', 'villa', 'composee', 'salon', 'plus', 'chambres', 'cuisine', 'equipee', 'sdb', 'climatiseurs', 'terrasse', 'pres', 'gare', 'toute', 'commodites', 'tel', 'rades', 'melianerades', 'meliane']
# 1542
# ['a', 'vendre', 'villa', 'style', 'arabesque', 'sallon', 'trois', 'chambres', 'surgit', 'terrain', 'situe', 'coeur', 'sidi', 'bousaid', 'dote', 'bon', 'voisinage', 'villa', 'compose', 'comme', 'suit', 'rez', 'chaussee', 'salon', 'cuisine', 'amenagee', 'salle', 'bain', 'chambre', 'premiere', 'etage', 'trois', 'chambres', 'a', 'coucher', 'dont', 'deux', 'ouvrent', 'balcon', 'salle', 'bain', 'salle', 'bain', 'villa', 'equipee', 'chauffage', 'central', 'climatisation', 'split', 'systeme', 'prix', 'dt', 'hesitez', 'a', 'contacter', 'tous', 'renseignements', 'visites', 'sidi', 'bousaidsidi', 'bousaid']
# 1543
# ['av', 'maison', 'rdc', 'entree', 'independante', 'emplacement', 'exceptionnel', ',', 'facade', 'ouvre', 'rue', 'stade', 'porte', 'arriere', 'ouvre', 'parking', 'voitures', ',', 'superficie', 'terrain', ',', ',', 'superficie', 'bati', ',', 'villa', 'compose', 'sallon', 'trois', 'chambres', ',', 'ssm', ',', 'cuisine', ',', 'sdb', ',', 'salle', 'bain', ',', 'abri', 'garage', ',', 'cuisine', 'exterieure', 'jardin', ',', 'titre', 'propriete', ',', 'prix', 'md', ',', 'tel', ',', ',', 'cite', 'juges', 'marsacite', 'juges']
# 1544
# ['a', 'vendre', 'bureau', 'h', 'premiere', 'etage', 'superficie', 'situe', 'a', 'ain', 'zaghouan', 'artere', 'principale', 'a', 'fort', 'achalandage', 'avenue', 'khaled', 'ibn', 'walid', 'compose', 'comme', 'suit', 'hall', 'deux', 'piece', 'kitchenette', 'salle', 'bain', 'bureau', 'equipe', 'chauffage', 'central', 'climatisation', 'split', 'system', 'place', 'parking', 'sou', 'sol', 'disponible', 'prix', 'dt', 'hesitez', 'a', 'contacter', 'tous', 'renseignements', 'visites', 'ain', 'zaghoueneain', 'zaghouan']
# 1545
# ['fb', 'contacter', 'conseillere', 'immobiliere', 'agence', 'immobiliere', 'ari', 'propose', 'a', 'vendre', 'appartement', 'sallon', 'trois', 'chambres', 'grand', 'terrasse', 'residence', 'r', 'assesseur', 'tres', 'haut', 'standing', 'situe', 'a', 'hammamet', 'mrezga', 'afh', 'nabeul', 'quartier', 'residentiel', 'proche', 'toutes', 'commodites', 'compose', 'salon', ',', 'cuisine', 'bien', 'equipee', 'plaque', 'element', 'rangement', 'plus', 'sechoir', ',', 'chambres', 'a', 'coucher', 'plus', 'salle', 'douche', 'salle', 'bain', 'appartement', 'installe', 'chauffage', 'centrale', 'climatisation', 'agence', 'immobiliere', 'ari', 'hammamet', 'mrezga', 'afhcite', 'afh']
# 1546
# ['vente', 'appartement', 'sallon', 'deux', 'chambres', 'petit', 'immeuble', 'calme', 'etages', 'situe', 'a', 'cite', 'jardin', ',', 'sfax', ',', 'titre', 'foncier', 'constitue', 'salon', 'chambres', 'a', 'coucher', 'hall', 'salle', 'bain', 'grande', 'cuisine', 'sechoir', 'petite', 'buanderie', 'a', 'proximite', 'toutes', 'commodites', 'clinique', ',', 'etablissements', 'enseignement', ',', 'etc', 'prix', 'a', 'debattre', 'contacter', 'cite', 'jardin']
# 1547
# ['a', 'vendre', 'terrain', 'm2', 'situe', 'a', 'hmayem', 'route', 'el', 'margueb', 'emplacement', 'tres', 'calme', 'vue', 'montagne', 'faisant', 'angle', 'unere', 'position', 'facade', 'route', 'principale', 'el', 'margueb', 'terrain', 'trouve', 'a', 'km', 'el', 'mornaguia', 'centre', 'a', 'km', 'neopark', 'el', 'fejja', 'terrain', 'peut', 'etre', 'utilise', 'a', 'fin', 'residentielles', 'commerciales', 'exemple', 'depot', 'magasinage', 'agricole', 'terrain', 'titre', 'papiers', 'regle', 'disponibilite', 'toutes', 'commodites', 'contacter', 'el', 'hamayem']
# 1548
# ['a', 'vendre', 'fond', 'commerce', 'fast', 'food', 'materiel', 'berges', 'lac', 'face', 'ambassade', 'argentine', 'rue', 'victoria', 'prix', 'dt', 'loyer', 'dt', 'hesitez', 'a', 'contacter', 'tous', 'renseignements', 'visites', 'berge', 'lac']
# 1549
# ['a', 'vendre', 'appartement', 'sallon', 'deux', 'chambres', 'unere', 'etage', 'sans', 'ascenseur', 'a', 'cite', 'el', 'zouhour', 'bardo', 'i', 'appartement', 'compose', 'comme', 'suit', 'salon', 'cuisine', 'deux', 'chambres', 'a', 'coucher', 'salle', 'bain', 'prix', 'dt', 'hesitez', 'a', 'contacter', 'tous', 'renseignements', 'visites', 'cite', 'ezzouhour', 'bardo']
# 1550
# ['a', 'vendre', 'appartement', 'sallon', 'deux', 'chambres', 'troiseme', 'etage', 'ascenseur', 'superficie', 'berges', 'lac', 'pres', 'hotel', 'movempick', 'appartement', 'compose', 'comme', 'suit', 'salon', 'salle', 'a', 'manger', 'cuisine', 'amenagee', 'equipee', 'sechoir', 'coin', 'arabesque', 'suite', 'parentale', 'dressing', 'salle', 'douche', 'chambre', 'a', 'coucher', 'dressing', 'salle', 'bain', 'appartement', 'equipee', 'chauffage', 'central', 'climatisation', 'split', 'systeme', 'place', 'parking', 'sou', 'sol', 'cellier', 'disponibles', 'prix', 'dt', 'hesitez', 'a', 'contacter', 'tous', 'renseignements', 'visites', 'berge', 'lac']
# 1551
# ['a', 'vendre', 'appartement', 'situe', 'etage', 'compose', 'salon', 'plus', 'chambres', 'cuisine', 'equipee', 'sdb', 'climatiseurs', 'chauffage', 'centrale', 'place', 'parking', 'sou', 'sol', 'titre', 'foncier', 'individuel', 'contacter', 'rades', 'melianerades']
# 1552
# ['agence', 'ranime', 'immo', 'propose', 'vente', 'maison', 'sallon', 'deux', 'chambres', ',', 'cuisine', ',', 'salle', 'bain', ',', 'terrasse', 'jardin', 'bien', 'placee', 'em', 'position', 'situee', 'quartier', 'calme', 'a', 'plage', 'el', 'haouaria', 'cap', 'bon', 'surface', 'terrain', 'surface', 'couverte', 'cette', 'maison', 'construite', 'autorisation', 'batir', 'equipee', 'compteur', 'steg', 'compteur', 'soned', 'dossier', 'foncier', 'regle', 'prix', 'dt', 'serieux', 'occasion', 'a', 'rater', 'agence', 'a', 'disposition', 'toutes', 'information', 'conseils', 'necessaires', 'afin', 'disposer', 'bien', 'tel', 'whatsapp', 'fcb', 'ranime', 'immoa', 'plage', 'el', 'haouaria', 'cap', 'boncite', 'touristique']
# 1553
# ['a', 'vendre', 'sallon', 'chambres', ',', 'residence', 'simpar', 'cuisine', 'moderne', 'entierement', 'equipee', 'four', ',', 'hote', ',', 'frigidaire', 'encastre', 'salle', 'bain', 'douche', 'a', 'italienne', 'placard', 'systeme', 'alarmemenzah', 'cel', 'menzah']
# 1554
# ['ketata', 'immo', 'met', 'vente', 'a', 'ennasr', 'derriere', 'clinique', 'ennasr', ',', 'spacieux', 'sallon', 'trois', 'chambres', ',', 'quatrieme', 'dernier', 'etage', 'ascenseur', 'appart', 'haut', 'standing', ',', 'vue', 'degagee', ',', 'terrasse', 'chauffage', 'central', ',', 'clim', ',', 'sde', ',', 'sdb', 'douche', ',', 'fenetre', 'alu', ',', 'revetement', 'sol', 'marbre', 'blanc', ',', 'place', 'parking', ',', 'plus', 'info', 'visite', 'veuillez', 'contacter', 'courtier', 'mr', 'ketata', 'chafik', 'tel', 'whatsapp', 'cite', 'ennasr']
# 1555
# ['a', 'vendre', 'duplex', 'sallon', 'trois', 'chambres', 'bel', 'emplacement', 'a', 'ezzahra', 'quartier', 'calme', 'securise', 'salon', 'salle', 'a', 'manger', 'chambres', 'balcon', 'couvert', 'salle', 'bain', 'salle', 'bain', 'cuisine', 'sechoir', 'gaz', 'ville', 'chauffage', 'central', 'jardin', 'abri', 'voiture', 'superficie', 'batie', 'superficie', 'terrain', 'prix', 'md', 'plus', 'information', 'contactez', 'cite', 'el', 'ezz']
# 1556
# ['ketata', 'immo', 'met', 'vente', 'a', 'ennasr', 'derriere', 'monoprix', ',', 'spacieux', 'sallon', 'trois', 'chambres', ',', 'rdc', 'appart', 'bon', 'standing', 'chauffage', 'central', ',', 'clim', ',', 'sde', ',', 'sdb', ',', 'fenetre', 'alu', ',', 'revetement', 'sol', 'marbre', 'blanc', ',', 'place', 'parking', ',', 'plus', 'info', 'visite', 'veuillez', 'contacter', 'courtier', 'mr', 'ketata', 'chafik', 'tel', 'whatsapp', 'ennasr', 'cite', 'ennasr']

# %%
stop_words
# Out:
# {'ai',
#  'aie',
#  'aient',
#  'aies',
#  'ait',
#  'as',
#  'au',
#  'aura',
#  'aurai',
#  'auraient',
#  'aurais',
#  'aurait',
#  'auras',
#  'aurez',
#  'auriez',
#  'aurions',
#  'aurons',
#  'auront',
#  'aux',
#  'avaient',
#  'avais',
#  'avait',
#  'avec',
#  'avez',
#  'aviez',
#  'avions',
#  'avons',
#  'ayant',
#  'ayante',
#  'ayantes',
#  'ayants',
#  'ayez',
#  'ayons',
#  'c',
#  'ce',
#  'ces',
#  'd',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'es',
#  'est',
#  'et',
#  'eu',
#  'eue',
#  'eues',
#  'eurent',
#  'eus',
#  'eusse',
#  'eussent',
#  'eusses',
#  'eussiez',
#  'eussions',
#  'eut',
#  'eux',
#  'eûmes',
#  'eût',
#  'eûtes',
#  'furent',
#  'fus',
#  'fusse',
#  'fussent',
#  'fusses',
#  'fussiez',
#  'fussions',
#  'fut',
#  'fûmes',
#  'fût',
#  'fûtes',
#  'il',
#  'ils',
#  'j',
#  'je',
#  'l',
#  'la',
#  'le',
#  'les',
#  'leur',
#  'lui',
#  'm',
#  'ma',
#  'mais',
#  'me',
#  'mes',
#  'moi',
#  'mon',
#  'même',
#  'n',
#  'ne',
#  'nos',
#  'notre',
#  'nous',
#  'on',
#  'ont',
#  'ou',
#  'par',
#  'pas',
#  'pour',
#  'qu',
#  'que',
#  'qui',
#  's',
#  'sa',
#  'se',
#  'sera',
#  'serai',
#  'seraient',
#  'serais',
#  'serait',
#  'seras',
#  'serez',
#  'seriez',
#  'serions',
#  'serons',
#  'seront',
#  'ses',
#  'soient',
#  'sois',
#  'soit',
#  'sommes',
#  'son',
#  'sont',
#  'soyez',
#  'soyons',
#  'suis',
#  'sur',
#  't',
#  'ta',
#  'te',
#  'tes',
#  'toi',
#  'ton',
#  'tu',
#  'un',
#  'une',
#  'vos',
#  'votre',
#  'vous',
#  'y',
#  'à',
#  'étaient',
#  'étais',
#  'était',
#  'étant',
#  'étante',
#  'étantes',
#  'étants',
#  'étiez',
#  'étions',
#  'été',
#  'étée',
#  'étées',
#  'étés',
#  'êtes'}

# %%
text
# Out:
# 'il y a   chambres et   chambres    sejour et deux chambres septieme deuxieme to septieme  ere etage  '

# %%
import nltk

# Download and install the wordnet corpus
nltk.download('wordnet')

# Use the WordNetLemmatizer to lemmatize a word
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

word = "running"
lemma = lemmatizer.lemmatize(word, pos='v')
print(f"Original word: {word}, Lemmatized word: {lemma}")

# %%
#stemming

# %%
#langue detect
