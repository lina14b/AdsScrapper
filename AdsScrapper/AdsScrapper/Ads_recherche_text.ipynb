# %% [markdown]
# IMPORTS

# %%
from pymongo import MongoClient
from bienImmobilier import BienImmobilier
import pandas as pd
import numpy as np
from collections import Counter
import re
from spellchecker import SpellChecker
from num2words import num2words
import nltk
from nltk.corpus import wordnet as wn
import spacy
import nltk
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import unicodedata
from transformationText import TransformationTexte
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lina\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lina\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lina\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# Fill dataframe with text

# %%
b=BienImmobilier()
list=b.readAll()
t=TransformationTexte()

# %%
client = MongoClient("mongodb+srv://lina:lina@cluster0.st42f.mongodb.net/test")
db = client["AdsScrappers"]
collection = db["Ads"]

# %% [markdown]
# **first**

# %%
len(list)
#999
# Out:
# 13358

# %%
item=list[0]
i=0
# for item in list:
while i<1000:
     print("____________________________________________")
     item =list[i]
     print(i+1)
     test=0
     newdescription=" _ " 
     if item['description']:
      newdescription=newdescription+item['description']
     test=1
     if item['adresse']:
          newdescription=newdescription+item['adresse']######+df['ville']
          test=1
     if item['ville']:
          newdescription=newdescription+item['ville'].lower()
          test=1
     if item['nombre_de_chambre']:
          newdescription=newdescription+' s+ ' +str(item['nombre_de_chambre'])
          test=1
     if len(newdescription)<5:
         newdescription=" empty "
     print(i,newdescription)
     # print(i,item['description'])
     i=i+1
     new=t.transform(newdescription)
     print(new)
     result = collection.update_one({'url': item['url']},{'$set': {'total_description': new}})
# Out:
# ____________________________________________
# 1
# 0  _ l'agence immo contact met en vente a el manzah 9b pour 1180000 dt une villa sur 3 niveaux ( terrain 498m et bati 550m ) avec chauffage central , jardin , studio , garage , titre bleu (wb3157)  frais de visite 20dt , commission agence 2 pourcentel manzah 9bel menzah 9
# fr
# ['_', 'agenc', 'mme', 'contact', 'met', 'vent', 'a', 'el', 'mandat', 'neuf', 'b', 'vill', 'trois', 'niveau', 'terrain', 'quatr', 'bat', 'cinq', 'chauffag', 'central', 'jardin', 'studio', 'garag', 'titr', 'bleu', 'sept', 'frais', 'visit', 'deux', 'commiss', 'agenc', 'deux', 'pourcent', 'mandat', 'neuf', 'bel', 'mental', 'neuf']
# ____________________________________________
# 2
# ...

# %%
tn = "Dar odemha espace lkol 975 m2 3al b7ar bin saloum w yesmin Hammamet chambre (10 mn 3la yesmin Hammamet)"
fr="Maison au  وسط centre ville à 200m de la jarre et derrière Nabeul centre. Elle fait 3 façades. 100m2 bâti au rez de chaussée 2chambres, séjour et cuisine) et 120 m2 au premier étage (non fini). Total superficie 298m[hidden information]"
ar="s+ 3 لسنا 200 الشركة الوحيدة في صنع السلالم المعلقة لكننا الشركة الوحيد  في صنع السلالم المعلقة بالخرسانة الم... دار عربي 2 غرف+صالة+كوجينة   centre و ستوديو كامل طابقا اول2 غرف+ صالة كبيرة+ كوجينة في وسط  دار شعبان"

# %% [markdown]
# **French**

# %%
text=t.transform(fr)
print(fr)
print(text)
# Out:
# fr
# Maison au  وسط centre ville à 200m de la jarre et derrière Nabeul centre. Elle fait 3 façades. 100m2 bâti au rez de chaussée 2chambres, séjour et cuisine) et 120 m2 au premier étage (non fini). Total superficie 298m[hidden information]
# ['maison', 'وسط', 'centr', 'vill', 'deux', 'jarr', 'derri', 'label', 'centr', 'fait', 'trois', 'façad', 'bât', 'rez', 'chauss', 'deux', 'chambr', 'séjour', 'cuisin', 'premi', 'étag', 'non', 'fin', 'total', 'superfic', 'deux', 'hid', 'inform']

# %%
text=t.transform(ar)
print(ar)
print(text)
# Out:
# ar
# s+ 3 لسنا 200 الشركة الوحيدة في صنع السلالم المعلقة لكننا الشركة الوحيد  في صنع السلالم المعلقة بالخرسانة الم... دار عربي 2 غرف+صالة+كوجينة   centre و ستوديو كامل طابقا اول2 غرف+ صالة كبيرة+ كوجينة في وسط  دار شعبان
# ['غرف', 'صالة', 'ثلاث', 'الشركة', 'الوحيدة', 'صنع', 'السلالم', 'المعلقة', 'لكننا', 'الشركة', 'الوحيد', 'صنع', 'السلالم', 'المعلقة', 'بالخرسانة', 'الم', 'دار', 'عربي', 'اثنان', 'غرف', 'صالة', 'كوجينة', 'ستوديو', 'كامل', 'طابقا', 'اول', 'اثنان', 'غرف', 'صالة', 'كبيرة', 'كوجينة', 'وسط', 'دار', 'شعبان']

# %%
text=t.transform(tn)
print(tn)
print(text)
# Out:
# sv
# Dar odemha espace lkol 975 m2 3al b7ar bin saloum w yesmin Hammamet chambre (10 mn 3la yesmin Hammamet)
# ['dar', 'odemh', 'espac', 'lkol', 'neuf', 'trois', 'al', 'ar', 'bin', 'saloum', 'w', 'yesmin', 'hammamet', 'chambr', 'zéro', 'mn', 'trois', 'yesmin', 'hammamet']

# %% [markdown]
# **arabic**

# %%
from pyarabic.araby import strip_harakat
from pyarabic.araby import strip_tashkeel
from pyarabic.araby import strip_lastharaka
from pyarabic.araby import normalize_ligature
import pyarabic.araby as araby
from pyarabic.araby import tokenize, is_arabicrange, strip_tashkeel
import pyarabic.number
nltk.download('stopwords')
from nltk.corpus import stopwords
text = ar
text = text.lower()
text = re.sub(r"\s*\+\s*", "+", text)
def number_to_words(match):
    number = int(match.group(1))
    if number==0:
            return ""
    else: return " غرف و صالة"+" "+str(number)
text = re.sub(r"s\+(\d+)", number_to_words, text)
text = re.sub(r'\b(3[1-9]|[4-9]\d|\d{3,})\b', '', text)
text = re.sub(r'(\w)(\d)', r'\1 \2', text)
an = pyarabic.number.ArNumbers()
tokens = text.split()
new=""
for i in range(len(tokens)):
 word=tokens[i]
 if word.isdigit():
  word=an.int2str(tokens[i])
 new=new+" "+word      
text=new
strip_tashkeel(text)
strip_harakat(text)
normalize_ligature(text)
text =araby.normalize_hamza(text, method="tasheel")
tokens=tokenize(text, conditions=is_arabicrange, morphs=strip_tashkeel)
stop_words = set(stopwords.words('arabic'))
stop_words.difference_update({'صفر', 'واحد', 'اثنان', 'ثلاثة', 'أربعة', 'خمسة', 'ستة', 'سبعة', 'ثمانية', 'تسعة', 'عشرة'})
filtered_tokens = [token for token in tokens if not token in stop_words]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lina\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(ar)
print(text)
# Out:
# s+ 3 لسنا 200 الشركة الوحيدة في صنع السلالم المعلقة لكننا الشركة الوحيد  في صنع السلالم المعلقة بالخرسانة الم... دار عربي 2 غرف+صالة+كوجينة   centre و ستوديو كامل طابقا اول2 غرف+ صالة كبيرة+ كوجينة في وسط  دار شعبان
#  غرف و صالة ثلاث لسنا الشركة الوحيدة في صنع السلالم المعلقة لكننا الشركة الوحيد في صنع السلالم المعلقة بالخرسانة الم... دار عربي اثنان غرف+صالة+كوجينة centre و ستوديو كامل طابقا اول اثنان غرف+صالة كبيرة+كوجينة في وسط دار شعبان

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import pyarabic as pyAr
from nltk.stem import WordNetLemmatizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 7
#       5 import pyarabic
#       6 from nltk.stem import WordNetLemmatizer
# ----> 7 from pyarabic.nltk_support import ArabicTokenizer
#
# ModuleNotFoundError: No module named 'pyarabic.nltk_support'

# %%
text = ar

# Text cleaning
text = text.lower()
text = re.sub(r'[^\w\s]', ' ', text)
processed_text = re.sub(r'\b(3[1-9]|[4-9]\d|\d{3,})\b', '', text)
processed_text = re.sub(r'(\w)(\d)', r'\1 \2', processed_text)
print(processed_text)

# Tokenization
tokens = pyAr.tokenize(processed_text)

# Stopword removal
stop_words = set(stopwords.words('arabic'))
filtered_tokens = [token for token in tokens if not token in stop_words]

# Stemming
stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]

# Print the processed text
processed_text = " ".join(stemmed_tokens)

# Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
print(lemmatized_tokens)
# Print the processed text
processed_text = " ".join(lemmatized_tokens)


print(ar)
print(processed_text)
# Out:
# لسنا  الشركة الوحيدة في صنع السلالم المعلقة لكننا الشركة الوحيد  في صنع السلالم المعلقة بالخرسانة الم    دار عربي 2 غرف صالة كوجينة  و ستوديو كامل طابقا اول 2 غرف  صالة كبيرة  كوجينة في وسط  دار شعبان
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 11
#       8 print(processed_text)
#      10 # Tokenization
# ---> 11 tokens = pyAr.tokenize(processed_text)
#      13 # Stopword removal
#      14 stop_words = set(stopwords.words('arabic'))
#
# AttributeError: module 'pyarabic' has no attribute 'tokenize'

# %%
# spell = SpellChecker(language='fr')
# mots = "surface,chauffage,climatisation,ascenseur"
# liste_mots = mots.split(", ")
# nlp = spacy.load('fr_core_news_sm')

# %%
# list=b.readAll()
# df = pd.DataFrame(list)
# #df
# b.ReadbyUrl(list[0]['url'])
# b.print_maison()

# %%
# ################################################################to be deleted
# item=list[0]
# i=0
# #for item in list:
# print(i)
# i=i+1
# test=0
# newdescription=" _ " 
# if item['description']:
#     newdescription=newdescription+item['description']
#     test=1
# if item['adresse']:
#      newdescription=newdescription+item['adresse']######+df['ville']
#      test=1
# if item['nombre_de_chambre']:
#      newdescription=newdescription+' s+ ' +str(item['nombre_de_chambre'])
#      test=1

# #text = newdescription
# text=t.TransormRawText(newdescription)
#     ######################### deal with s+
#  def number_to_words(match):
#         number = int(match.group(1))
#         if number==0:
#          return ""
#         else: return "sallon et {} chambres".format(num2words(number, lang='fr'))

#     # Replace patterns of the form "s+number" with "sallon et the number in letters"
#  text = re.sub(r"\s*\+\s*", "+", text)
#  text = re.sub(r"s\+(\d+)", number_to_words, text)
#  text = text.replace('éme', 'ème').replace(' ème', 'ème').replace('1er', '1ère').replace(' eme', 'ème').replace(' eau',' bain')
#  pattern = re.compile(r'\b([1-2]?\d{1,2}|1[0-9])\s*(ème|éme|er?)\b|[^\w\s,]|[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F1E0-\U0001F1FF]', re.MULTILINE)
#  text = pattern.sub(lambda match: num2words(int(match.group(1)), lang='fr') + match.group(2) if match.group(1) else ' ', text)
#  text = re.sub(r'\b(3[1-9]|[4-9]\d|\d{3,})\b', '', text)
#  text = re.sub(r'\b([0-9])\b', lambda match: ["zéro", "un", "deux", "trois", "quatre", "cinq", "six", "sept", "huit", "neuf"][int(match.group(1))], text)

#  text = re.sub(r'\b\w*\d+\w*\b', '', text)
#  text = re.sub(r'\b(\d+)(ère|ème|er?)\b', lambda match: num2words(int(match.group(1)), lang='fr') + match.group(2), text)
#  text = re.sub(r'\d+', ' ', text)
#  text = text.replace('\n', ' ').replace('\r', ' ')
#  misspelled = spell.unknown(text.split())
#  for word in misspelled:
#     corrected_word = spell.correction(word)
#     if corrected_word:
#         text = text.replace(word, corrected_word)
#  for mot in liste_mots:
#     target_word =mot
#     doc = nlp(text)
#     lemmas = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
#     synsets = wn.synsets(target_word, lang='fra')
#     synonyms = set()
#     for synset in synsets:
#         for lemma in synset.lemmas(lang='fra'):
#             synonyms.add(lemma.name())

#         # Check if any of the lemmas match any of the synonyms
#     detected_synonyms = set()
#     for lemma in lemmas:
#         if lemma in synonyms:
#             detected_synonyms.add(lemma)

#         # Print the detected synonyms
#     if len(detected_synonyms) > 0:
#         for ds in detected_synonyms:
#             text=text.replace(ds,mot)

if item['ville']:
     newdescription=text+ item['ville'].lower()
result = collection.update_one({'url': item['url']},{'$set': {'total_description': newdescription}})
print(text)

#  if result.modified_count == 1:
#       i=i+1
#       print(i)
# Out:
# 0
#  _ l agence mme contact met en vente a el mandat  pour  de une villa sur trois niveaux   terrain  et bat    avec chauffage central , jardin , studio , garage , titre bleu     frais de visite  , commission agence deux pourcent mandat

# %% [markdown]
# DATA FRAME SHIT

# %%
###############################################################################################################################
dfcopy=df

# %%
df
# Out:
#                   website                                                url  \
# 0       tunisie-vente.com  http://www.tunisie-vente.com/DetailsOffre.asp?...
# 1       tunisie-vente.com  http://www.tunisie-vente.com/DetailsOffre.asp?...
# 2       tunisie-vente.com  http://www.tunisie-vente.com/DetailsOffre.asp?...
# 3       tunisie-vente.com  http://www.tunisie-vente.com/DetailsOffre.asp?...
# 4       tunisie-vente.com  http://www.tunisie-vente.com/DetailsOffre.asp?...
# ...                   ...                                                ...
# 1552  tunisie-annonce.com  http://www.tunisie-annonce.com/DetailsAnnonceI...
# 1553    tunisie-vente.com  http://www.tunisie-vente.com/DetailsOffre.asp?...
# 1554  tunisie-annonce.com  http://www.tunisie-annonce.com/DetailsAnnonceI...
# 1555  tunisie-annonce.com  http://www.tunisie-annonce.com/DetailsAnnonceI...
# 1556  tunisie-annonce.com  http://www.tunisie-annonce.com/DetailsAnnonceI...
#
# ...

# %%
df=dfcopy

# %%
df = df[df['description'].notnull()]

# %%
# df['description'] = df['description'].fillna(' ')
df['ville'] = df['ville'].fillna(' ')
df['adresse'] = df['adresse'].fillna(' ')
df['TotalDescp'] = df['TotalDescp'].fillna(' ')
df['nombre_de_chambre'] = df['nombre_de_chambre'].fillna(0)
df['TotalDescp_']=df['TotalDescp']+df['description']+df['adresse']+df['ville']+ 's+ ' + df['nombre_de_chambre'].astype(str)

# %%
null_count = df['TotalDescp_'].isnull().sum()
null_count
# Out:
# 0

# %%
desp=df['TotalDescp_'].tolist()
