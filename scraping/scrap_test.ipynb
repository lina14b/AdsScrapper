# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

data=[]

class ListingType():
    def __init__(self): 
        self.titre = None 
        self.category = None
        # self.description = None
        self.place = None
        self.prix = None

page_count = 0
while page_count < 2:

    url = "https://www.tayara.tn/search/?category=Immobilier?page=%d" %(page_count)
    
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    property_listings = soup.find_all("div", class_="p-0 px-3 z-10 flex-none -mt-1")
    
    for property_listing in property_listings:
        listing=ListingType()
        category = property_listing.find("span",class_="truncate text-3xs md:text-xs lg:text-xs w-3/5 font-medium text-neutral-500").text
        if (category in ["Colocations", "Maisons et Villas", "Magasins, Commerces et Locaux industriels", "Locations de vacances", "Appartements", "Bureaux et Plateaux", "Autres Immobiliers", "Terrains et Fermes", "Meubles et Décoration"]):
            listing.category = category
            # description = property_listing.find("h2",class_="card-title font-arabic text-sm font-medium leading-5 text-gray-800 max-w-min min-w-full line-clamp-2 mb-2 mt-1").text
            # listing.description = description
            place= property_listing.find("span",class_="line-clamp-1 truncate text-3xs md:text-xs lg:text-xs w-3/5 font-medium text-neutral-500").text
            listing.place = place
            prix= property_listing.select_one("data",class_="text-red-600 font-bold font-arabic  undefined").attrs.get("value", None)
            listing.prix = prix
            titre= property_listing.find("h2",class_="card-title font-arabic text-sm font-medium leading-5 text-gray-800 max-w-min min-w-full line-clamp-2 mb-2 mt-1").text
            listing.titre = titre
            
            data.append(listing)

    page_count += 1

# print(len(data))

file = open('scraped.csv', 'w', encoding="utf-8")
writer = csv.writer(file)
writer.writerow(['titre', 'Categorie', 'Ville', 'prix'])

for listing in data:
    writer.writerow([listing.titre, listing.category, listing.place, listing.prix])

df=pd.read_csv('scraped.csv')

df
# Out:
#                                                 titre
# 0                       S+1 à louer pour les vacances  \
# 1   Local de 50 mettres carrés plein centre ville ...
# 2   A vendre #Terrain d'angle faisant 571m² à khez...
# 3   Location usine de 3450m² dans la zone industri...
# 4                 Local commercial à louer à l'Mnihla
# 5                                 Location studio s+1
# 6   en location un luxueux bureau de type A+2 situ...
# 7   (85م) أرض للبيع قرب المحكمة و الولاية بن عروس ...
# 8                           fond de commerce à vendre
# 9                       S+1 à louer pour les vacances
# 10  Local de 50 mettres carrés plein centre ville ...
# 11  A vendre #Terrain d'angle faisant 571m² à khez...
# 12  Location usine de 3450m² dans la zone industri...
# 13                Local commercial à louer à l'Mnihla
# 14                                Location studio s+1
# 15  en location un luxueux bureau de type A+2 situ...
# 16  (85م) أرض للبيع قرب المحكمة و الولاية بن عروس ...
# 17                          fond de commerce à vendre
#
#                                     Categorie                      Ville
# 0                                Appartements      Nabeul, 3 minutes ago  \
# 1   Magasins, Commerces et Locaux industriels       Tunis, 3 minutes ago
# 2                          Terrains et Fermes      Sousse, 4 minutes ago
# 3   Magasins, Commerces et Locaux industriels  La Manouba, 5 minutes ago
# 4   Magasins, Commerces et Locaux industriels      Ariana, 5 minutes ago
# 5                       Locations de vacances      Nabeul, 6 minutes ago
# 6                         Bureaux et Plateaux      Sousse, 7 minutes ago
# 7                          Terrains et Fermes   Ben Arous, 7 minutes ago
# 8   Magasins, Commerces et Locaux industriels      Ariana, 7 minutes ago
# 9                                Appartements      Nabeul, 3 minutes ago
# 10  Magasins, Commerces et Locaux industriels       Tunis, 3 minutes ago
# 11                         Terrains et Fermes      Sousse, 4 minutes ago
# 12  Magasins, Commerces et Locaux industriels  La Manouba, 5 minutes ago
# 13  Magasins, Commerces et Locaux industriels      Ariana, 5 minutes ago
# 14                      Locations de vacances      Nabeul, 6 minutes ago
# 15                        Bureaux et Plateaux      Sousse, 7 minutes ago
# 16                         Terrains et Fermes   Ben Arous, 7 minutes ago
# 17  Magasins, Commerces et Locaux industriels      Ariana, 7 minutes ago
#
#       prix
# 0      100
# 1     1600
# 2     1250
# 3       60
# 4      650
# 5      350
# 6     1500
# 7   119000
# 8   123456
# 9      100
# 10    1600
# 11    1250
# 12      60
# 13     650
# 14     350
# 15    1500
# 16  119000
# 17  123456
